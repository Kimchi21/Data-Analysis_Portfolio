# %% [markdown]
# ## Loading the Google Fit Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/Daily activity metrics.csv', parse_dates=['Date'])

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df
# Out:
#           Date  Move Minutes count  Calories (kcal)  Distance (m)
# 0   2023-02-05                13.0       344.123961    524.760021  \
# 1   2023-02-06                39.0      1713.058600   2403.339113
# 2   2023-02-07                55.0      1777.036000   1997.674479
# 3   2023-02-08                 1.0      1552.000015     42.917145
# 4   2023-02-09                66.0      1768.063493   3417.347695
# ..         ...                 ...              ...           ...
# 283 2023-11-15                14.0      1582.313355    364.357379
# 284 2023-11-16                 5.0      1577.378352    260.005426
# 285 2023-11-17                23.0      1643.801985   1001.145217
# 286 2023-11-18                27.0      1624.597091   1114.314060
# 287 2023-11-19                 9.0      1151.974239    310.692350
#
#      Heart Points  Heart Minutes  Low latitude (deg)  Low longitude (deg)
# 0             3.0            3.0                 NaN                  NaN  \
# 1            24.0           24.0                 NaN                  NaN
# 2             6.0            6.0                 NaN                  NaN
# 3             NaN            NaN                 NaN                  NaN
# 4            23.0           22.0                 NaN                  NaN
# ..            ...            ...                 ...                  ...
# 283           NaN            NaN                 NaN                  NaN
# 284           NaN            NaN                 NaN                  NaN
# 285           1.0            1.0                 NaN                  NaN
# 286           5.0            5.0                 NaN                  NaN
# 287           NaN            NaN                 NaN                  NaN
#
#      High latitude (deg)  High longitude (deg)  Average speed (m/s)
# 0                    NaN                   NaN             0.706219  \
# 1                    NaN                   NaN             0.503210
# 2                    NaN                   NaN             0.556256
# 3                    NaN                   NaN             0.686918
# 4                    NaN                   NaN             0.627874
# ..                   ...                   ...                  ...
# 283                  NaN                   NaN             0.294014
# 284                  NaN                   NaN             0.289057
# 285                  NaN                   NaN             0.351925
# 286                  NaN                   NaN             0.371650
# 287                  NaN                   NaN             0.320458
#
#      Max speed (m/s)  Min speed (m/s)  Step count  Average weight (kg)
# 0           1.119866         0.289004         876                 78.5  \
# 1           1.529837         0.289004        3909                  NaN
# 2           1.259355         0.260104        3654                  NaN
# 3           1.084831         0.289004         163                  NaN
# 4           1.728785         0.269737        5742                  NaN
# ..               ...              ...         ...                  ...
# 283         0.397649         0.262337         711                  NaN
# 284         0.535820         0.262337         592                  NaN
# 285         1.268060         0.272054        1803                  NaN
# 286         1.206944         0.258449        2076                  NaN
# 287         0.929716         0.250361         701                  NaN
#
#      Max weight (kg)  Min weight (kg)  Biking duration (ms)
# 0               79.0             78.0                   NaN  \
# 1                NaN              NaN                   NaN
# 2                NaN              NaN                   NaN
# 3                NaN              NaN                   NaN
# 4                NaN              NaN                   NaN
# ..               ...              ...                   ...
# 283              NaN              NaN                   NaN
# 284              NaN              NaN                   NaN
# 285              NaN              NaN                   NaN
# 286              NaN              NaN                   NaN
# 287              NaN              NaN                   NaN
#
#      Walking duration (ms)  Running duration (ms)
# 0                 499980.0                    NaN
# 1                2502062.0                    NaN
# 2                3495956.0                    NaN
# 3                      NaN                    NaN
# 4                3356567.0                    NaN
# ..                     ...                    ...
# 283               374247.0                    NaN
# 284               297495.0                    NaN
# 285              1330554.0                    NaN
# 286              1031868.0                    NaN
# 287                84841.0                    NaN
#
# [288 rows x 20 columns]

# %%
df.shape
# Out:
# (288, 20)

# %%
df.columns
# Out:
# Index(['Date', 'Move Minutes count', 'Calories (kcal)', 'Distance (m)',
#        'Heart Points', 'Heart Minutes', 'Low latitude (deg)',
#        'Low longitude (deg)', 'High latitude (deg)', 'High longitude (deg)',
#        'Average speed (m/s)', 'Max speed (m/s)', 'Min speed (m/s)',
#        'Step count', 'Average weight (kg)', 'Max weight (kg)',
#        'Min weight (kg)', 'Biking duration (ms)', 'Walking duration (ms)',
#        'Running duration (ms)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   288 non-null    datetime64[ns]
#  1   Move Minutes count     280 non-null    float64
#  2   Calories (kcal)        288 non-null    float64
#  3   Distance (m)           287 non-null    float64
#  4   Heart Points           202 non-null    float64
#  5   Heart Minutes          202 non-null    float64
#  6   Low latitude (deg)     45 non-null     float64
#  7   Low longitude (deg)    45 non-null     float64
#  8   High latitude (deg)    45 non-null     float64
#  9   High longitude (deg)   45 non-null     float64
#  10  Average speed (m/s)    287 non-null    float64
#  11  Max speed (m/s)        287 non-null    float64
#  12  Min speed (m/s)        287 non-null    float64
#  13  Step count             288 non-null    int64
#  14  Average weight (kg)    1 non-null      float64
#  15  Max weight (kg)        1 non-null      float64
#  16  Min weight (kg)        1 non-null      float64
#  17  Biking duration (ms)   31 non-null     float64
#  18  Walking duration (ms)  276 non-null    float64
#  19  Running duration (ms)  7 non-null      float64
# dtypes: datetime64[ns](1), float64(18), int64(1)
# memory usage: 45.1 KB

# %%
df.nunique()
# Out:
# Date                     288
# Move Minutes count       122
# Calories (kcal)          280
# Distance (m)             287
# Heart Points              82
# Heart Minutes             84
# Low latitude (deg)        45
# Low longitude (deg)       41
# High latitude (deg)       45
# High longitude (deg)      43
# Average speed (m/s)      287
# Max speed (m/s)          286
# Min speed (m/s)           85
# Step count               281
# Average weight (kg)        1
# Max weight (kg)            1
# Min weight (kg)            1
# Biking duration (ms)      31
# Walking duration (ms)    276
# Running duration (ms)      7
# dtype: int64

# %%
df.describe()
# Out:
#                       Date  Move Minutes count  Calories (kcal)  Distance (m)
# count                  288          280.000000       288.000000    287.000000  \
# mean   2023-06-28 12:00:00           53.125000      1738.679198   2774.477679
# min    2023-02-05 00:00:00            1.000000       344.123961     16.323211
# 25%    2023-04-17 18:00:00           11.000000      1579.173576    323.333376
# 50%    2023-06-28 12:00:00           45.000000      1697.306995   2088.529088
# 75%    2023-09-08 06:00:00           86.000000      1881.628713   4352.080588
# max    2023-11-19 00:00:00          185.000000      2282.844325   9884.408530
# std                    NaN           44.529344       193.766559   2622.430201
#
#        Heart Points  Heart Minutes  Low latitude (deg)  Low longitude (deg)
# count    202.000000     202.000000           45.000000            45.000000  \
# mean      38.618812      37.831683           13.927202           121.239463
# min        1.000000       1.000000           13.751509           121.055916
# 25%       12.000000      12.000000           13.785361           121.069427
# 50%       30.500000      30.000000           13.786517           121.073395
# 75%       54.750000      53.750000           14.169380           121.129890
# max      120.000000     120.000000           14.172596           121.924736
# std       32.149963      32.047871            0.169711             0.322585
#
#        High latitude (deg)  High longitude (deg)  Average speed (m/s)
# count            45.000000             45.000000           287.000000  \
# mean             13.989849            121.258391             0.584684
# min              13.756069            121.066666             0.271737
# 25%              13.786919            121.074745             0.362172
# 50%              14.003397            121.136581             0.508940
# 75%              14.172587            121.150146             0.618012
# max              14.235782            121.928398             3.224944
# std               0.169614              0.315785             0.429811
#
#        Max speed (m/s)  Min speed (m/s)    Step count  Average weight (kg)
# count       287.000000       287.000000    288.000000                  1.0  \
# mean          2.561070         0.260540   4620.145833                 78.5
# min           0.272054         0.013915     16.000000                 78.5
# 25%           1.097823         0.250470    767.750000                 78.5
# 50%           1.263933         0.260104   3476.000000                 78.5
# 75%           1.770635         0.272054   7379.750000                 78.5
# max          28.846209         0.570798  16077.000000                 78.5
# std           4.284320         0.043269   4166.924741                  NaN
#
#        Max weight (kg)  Min weight (kg)  Biking duration (ms)
# count              1.0              1.0          3.100000e+01  \
# mean              79.0             78.0          1.084108e+06
# min               79.0             78.0          8.512000e+04
# 25%               79.0             78.0          5.474895e+05
# 50%               79.0             78.0          1.113215e+06
# 75%               79.0             78.0          1.460801e+06
# max               79.0             78.0          3.556767e+06
# std                NaN              NaN          7.516521e+05
#
#        Walking duration (ms)  Running duration (ms)
# count           2.760000e+02               7.000000
# mean            2.960304e+06          156922.000000
# min             3.384700e+04           68205.000000
# 25%             5.477638e+05           92015.000000
# 50%             2.269888e+06          120067.000000
# 75%             4.989991e+06          217203.000000
# max             1.090160e+07          291746.000000
# std             2.577616e+06           84890.575388

# %%
df.isnull().sum()
# Out:
# Date                       0
# Move Minutes count         8
# Calories (kcal)            0
# Distance (m)               1
# Heart Points              86
# Heart Minutes             86
# Low latitude (deg)       243
# Low longitude (deg)      243
# High latitude (deg)      243
# High longitude (deg)     243
# Average speed (m/s)        1
# Max speed (m/s)            1
# Min speed (m/s)            1
# Step count                 0
# Average weight (kg)      287
# Max weight (kg)          287
# Min weight (kg)          287
# Biking duration (ms)     257
# Walking duration (ms)     12
# Running duration (ms)    281
# dtype: int64

# %% [markdown]
# There's alot of missing values in the data.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There seems to be no duplicate values.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Dropping Columns

# %% [markdown]
# The columns that I'm gonna keep are the ones that are needed for the analysis.
#
# So the columns I'm dropping are:
# - Low latitude (deg)
# - Low longitude (deg)
# - High latitude (deg)
# - High longitude (deg)
# - Average weight (kg)
# - Max weight (kg)
# - Min weight (kg)
#
# The reason I'm dropping location coordinates is because I do not have a use for them yet. Unfortunately I wanted to keep the weight metrics becuase I want to keep track of my weight overtime but I didn't keep track or updated my weight everyday so the only time I did set my weight was at the beginning so that is the only record it has.

# %%
columns_to_drop = [
    'Low latitude (deg)',
    'Low longitude (deg)',
    'High latitude (deg)',
    'High longitude (deg)',
    'Average weight (kg)',
    'Max weight (kg)',
    'Min weight (kg)'
]

df.drop(columns=columns_to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Move Minutes count', 'Calories (kcal)', 'Distance (m)',
#        'Heart Points', 'Heart Minutes', 'Average speed (m/s)',
#        'Max speed (m/s)', 'Min speed (m/s)', 'Step count',
#        'Biking duration (ms)', 'Walking duration (ms)',
#        'Running duration (ms)'],
#       dtype='object')

# %% [markdown]
# ### Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Date                       0
# Move Minutes count         8
# Calories (kcal)            0
# Distance (m)               1
# Heart Points              86
# Heart Minutes             86
# Average speed (m/s)        1
# Max speed (m/s)            1
# Min speed (m/s)            1
# Step count                 0
# Biking duration (ms)     257
# Walking duration (ms)     12
# Running duration (ms)    281
# dtype: int64

# %% [markdown]
# #### Move Minutes count

# %%
missing_MMC = df[df['Move Minutes count'].isnull()]
missing_MMC
# Out:
#           Date  Move Minutes count  Calories (kcal)  Distance (m)
# 12  2023-02-17                 NaN      1555.512577     19.652272  \
# 16  2023-02-21                 NaN      1552.000015           NaN
# 144 2023-06-29                 NaN      1559.086678    119.564386
# 159 2023-07-14                 NaN      1559.139719     97.683354
# 185 2023-08-09                 NaN      1561.054749     57.222793
# 206 2023-08-30                 NaN      1555.341095     19.074264
# 247 2023-10-10                 NaN      1558.250009     34.978308
# 257 2023-10-20                 NaN      1563.698174     16.323211
#
#      Heart Points  Heart Minutes  Average speed (m/s)  Max speed (m/s)
# 12            NaN            NaN             0.601827         0.632855  \
# 16            NaN            NaN                  NaN              NaN
# 144           NaN            NaN             0.568002         1.073668
# 159           NaN            NaN             0.282672         0.315926
# 185           NaN            NaN             0.287087         0.289004
# 206           NaN            NaN             0.289004         0.289004
# 247           NaN            NaN             0.276912         0.291486
# 257           NaN            NaN             0.272054         0.272054
#
#      Min speed (m/s)  Step count  Biking duration (ms)  Walking duration (ms)
# 12          0.570798         124                   NaN                54568.0  \
# 16               NaN          16                   NaN                    NaN
# 144         0.289004         287                   NaN               110092.0
# 159         0.250470         343                   NaN               110916.0
# 185         0.269737         150               85120.0                49816.0
# 206         0.289004         109                   NaN                51904.0
# 247         0.262337         125                   NaN                    NaN
# 257         0.272054         114                   NaN                84733.0
#
#      Running duration (ms)
# 12                     NaN
# 16                     NaN
# 144                    NaN
# 159                    NaN
# 185                    NaN
# 206                    NaN
# 247                    NaN
# 257                    NaN

# %% [markdown]
# There are a total of 8 values missing from this column. The way this data is tracked is by calculating all their activity. Tracking for this data is a bit inconsistent since I'm also looking at values with similar metrics however they have records in this column. My solution is to based it on Step count so I give 3 count to the 343, and the rest is 1. However I noticed that the second row has almost all null values and the step count is only 16. This means that this column is the one with missing values of distance, and speed, I'm more inclined to delete this row.

# %%
# Delete that one row
null_counts = df[df['Step count'] == 16].isnull().sum(axis=1)
row_to_delete = null_counts[null_counts >= 6].index
df.drop(row_to_delete, inplace=True)

def fill_move_minutes(row):
    if pd.isnull(row['Move Minutes count']):
        if row['Step count'] == 343:
            return 3
        else:
            return 1
    else:
        return row['Move Minutes count']

df['Move Minutes count'] = df.apply(fill_move_minutes, axis=1)

# %% [markdown]
# #### Activity Duration

# %% [markdown]
# There are alot of values missing on the Biking and Running Duration since most of the physical activity I do is walking. I will calculate the total activity duration by summing all 3 values to create a new column for Total Duration.

# %%
df['Biking duration (ms)'].fillna(0, inplace=True)
df['Walking duration (ms)'].fillna(0, inplace=True)
df['Running duration (ms)'].fillna(0, inplace=True)

df['Total Duration (ms)'] = df['Biking duration (ms)'] + df['Walking duration (ms)'] + df['Running duration (ms)']

# %% [markdown]
# #### Heart Points and Minutes

# %% [markdown]
# This data records the total Heart Points that a user has obtained from all of their activities. Every data point shows how many Heart Points were determined over a certain period of time.
#
# User's can set a daily Heart Point goal and track their progress. Heart Points can be calculated using:
# - heart rate
# - Metabolic Equivalent of Task (MET) values
# - walking speed
#
# The number of Heart Points earned depends on the intensity of the activity. Use this guide to calculate and write Heart Points:
# | Data              | 1 HP (Low-medium intensity activity)                          | 2 HPs (High intensity activity)                                           |
# |-------------------|----------------------------------------------------------------|----------------------------------------------------------------------------|
# | Heart rate        | 1 minute of activity at >50% maximum heart rate                 | 1 minute of activity at >70% max heart rate                                |
# | MET value         | 3-6 MET. For example, rowing or rock climbing                  | >6 MET. For example, HIIT, skiing, volleyball or football                  |
# | Walking speed     | 100-130 steps per minute                                       | >130 steps per minute                                                      |

# %% [markdown]
# Unfortunately manually calculating for Heart Points and Minutes is a very hard task since I don't have access to some sensor data and it is very hard to do even a approximation of point values. I am forced to drop the columns without any record of Heart Points and Minutes

# %%
df.dropna(subset=['Heart Points', 'Heart Minutes'], inplace=True)

# %%
df
# Out:
#           Date  Move Minutes count  Calories (kcal)  Distance (m)
# 0   2023-02-05                13.0       344.123961    524.760021  \
# 1   2023-02-06                39.0      1713.058600   2403.339113
# 2   2023-02-07                55.0      1777.036000   1997.674479
# 4   2023-02-09                66.0      1768.063493   3417.347695
# 5   2023-02-10                26.0      1629.597414   1388.207947
# ..         ...                 ...              ...           ...
# 279 2023-11-11               133.0      2032.112814   8131.019776
# 281 2023-11-13               102.0      1892.254939   6382.760388
# 282 2023-11-14                11.0      1609.428947    733.985522
# 285 2023-11-17                23.0      1643.801985   1001.145217
# 286 2023-11-18                27.0      1624.597091   1114.314060
#
#      Heart Points  Heart Minutes  Average speed (m/s)  Max speed (m/s)
# 0             3.0            3.0             0.706219         1.119866  \
# 1            24.0           24.0             0.503210         1.529837
# 2             6.0            6.0             0.556256         1.259355
# 4            23.0           22.0             0.627874         1.728785
# 5            12.0           12.0             0.428640         1.187284
# ..            ...            ...                  ...              ...
# 279          94.0           94.0             0.816370         1.232294
# 281          77.0           77.0             0.430930         1.297489
# 282           5.0            5.0             0.424409         1.268201
# 285           1.0            1.0             0.351925         1.268060
# 286           5.0            5.0             0.371650         1.206944
#
#      Min speed (m/s)  Step count  Biking duration (ms)  Walking duration (ms)
# 0           0.289004         876                   0.0               499980.0  \
# 1           0.289004        3909                   0.0              2502062.0
# 2           0.260104        3654                   0.0              3495956.0
# 4           0.269737        5742                   0.0              3356567.0
# 5           0.279371        2448                   0.0              1205483.0
# ..               ...         ...                   ...                    ...
# 279         0.252621       12865                   0.0              7369788.0
# 281         0.252621       10214                   0.0              5194637.0
# 282         0.272054        1277                   0.0               795965.0
# 285         0.272054        1803                   0.0              1330554.0
# 286         0.258449        2076                   0.0              1031868.0
#
#      Running duration (ms)  Total Duration (ms)
# 0                      0.0             499980.0
# 1                      0.0            2502062.0
# 2                      0.0            3495956.0
# 4                      0.0            3356567.0
# 5                      0.0            1205483.0
# ..                     ...                  ...
# 279                    0.0            7369788.0
# 281                    0.0            5194637.0
# 282                    0.0             795965.0
# 285                    0.0            1330554.0
# 286                    0.0            1031868.0
#
# [202 rows x 14 columns]

# %%
df.isnull().sum()                 ### Checking
# Out:
# Date                     0
# Move Minutes count       0
# Calories (kcal)          0
# Distance (m)             0
# Heart Points             0
# Heart Minutes            0
# Average speed (m/s)      0
# Max speed (m/s)          0
# Min speed (m/s)          0
# Step count               0
# Biking duration (ms)     0
# Walking duration (ms)    0
# Running duration (ms)    0
# Total Duration (ms)      0
# dtype: int64

# %% [markdown]
# There are no missing values.

# %%
df.shape
# Out:
# (202, 14)

# %% [markdown]
# The size of the data has changed from being 288 rows down to 202.

# %% [markdown]
# ## Key Insights

# %% [markdown]
# ### Performance Comparison

# %%
# Group by 'Date' and calculate total metrics for each day
daily_metrics = df.groupby('Date').agg({
    'Move Minutes count': 'sum',
    'Calories (kcal)': 'sum',
    'Heart Points': 'sum'
}).reset_index()

plt.figure(figsize=(10, 6))

# Bar plot for Move Minutes count
plt.subplot(311)
plt.bar(daily_metrics['Date'], daily_metrics['Move Minutes count'], color='blue')
plt.title('Move Minutes count per Day')
plt.xlabel('Date')
plt.ylabel('Move Minutes count')

# Bar plot for Calories burned
plt.subplot(312)
plt.bar(daily_metrics['Date'], daily_metrics['Calories (kcal)'], color='green')
plt.title('Calories burned per Day')
plt.xlabel('Date')
plt.ylabel('Calories')

# Bar plot for Heart Points gained
plt.subplot(313)
plt.bar(daily_metrics['Date'], daily_metrics['Heart Points'], color='red')
plt.title('Heart Points gained per Day')
plt.xlabel('Date')
plt.ylabel('Heart Points')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation/Performance Analysis

# %%
relevant_columns = ['Move Minutes count', 'Calories (kcal)', 'Heart Points', 'Heart Minutes', 'Move Minutes count', 'Distance (m)',
                    'Average speed (m/s)', 'Max speed (m/s)', 'Min speed (m/s)', 'Step count']

subset_df = df[relevant_columns]

correlation_matrix = subset_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Physical Activity Metrics')
plt.show()

# %% [markdown]
# 1. **Move Minutes count and Other Metrics**:
#  - Strong Positive Correlations: Move Minutes count shows strong positive correlations with most other metrics: Calories (kcal), Heart Points, Heart Minutes, Distance (m), and Step count. The correlations range from 0.955 to 1.000, indicating a strong positive linear relationship.
#  - Highly Correlated Metrics: Step count, Distance (m), Heart Points, Heart Minutes, and Calories (kcal) exhibit high positive correlations with Move Minutes count, indicating that as Move Minutes count increases, these metrics tend to increase consistently.
#
# 2. **Calories (kcal) and Other Metrics**: Calories (kcal) shows similar strong positive correlations as Move Minutes count with Heart Points, Heart Minutes, Distance (m), and Step count.
#
# 3. **Heart Points and Heart Minutes**:
#  - Extremely High Positive Correlation: Heart Points and Heart Minutes show an almost perfect positive correlation of 0.999986-0.999987, indicating an almost perfect linear relationship. An increase in Heart Points correlates nearly identically with an increase in Heart Minutes.
#
# 4. **Distance and Step count**: Distance and Step count are almost perfectly positively correlated (0.999607), showing that they tend to increase together consistently.
#
# 5. **Speed Metrics (Average speed, Max speed, Min speed)**:
#  - Negative Correlations: Speed metrics show negative correlations with most other metrics but are relatively weaker compared to the strong positive correlations observed earlier. As the speed metrics increase, there's a tendency for the Move Minutes count, Calories, Heart Points, and Heart Minutes to decrease.

# %% [markdown]
# ### Speed Analysis

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
df['Average speed (m/s)'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Average speed')
plt.xlabel('Average speed (m/s)')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
df['Max speed (m/s)'].plot(kind='hist', bins=20, color='salmon', edgecolor='black')
plt.title('Distribution of Max speed')
plt.xlabel('Max speed (m/s)')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
df['Min speed (m/s)'].plot(kind='hist', bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Min speed')
plt.xlabel('Min speed (m/s)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# desc

# %% [markdown]
# ### Activity Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame with the necessary columns

# Calculate the proportion of each activity duration to Total Duration
df['Biking_proportion'] = df['Biking duration (ms)'] / df['Total Duration (ms)']
df['Walking_proportion'] = df['Walking duration (ms)'] / df['Total Duration (ms)']
df['Running_proportion'] = df['Running duration (ms)'] / df['Total Duration (ms)']

# Set up the figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot (Activity Duration vs. Heart Points) using Seaborn
sns.scatterplot(data=df, x='Biking_proportion', y='Heart Points', label='Biking', ax=ax1)
sns.scatterplot(data=df, x='Walking_proportion', y='Heart Points', label='Walking', ax=ax1)
sns.scatterplot(data=df, x='Running_proportion', y='Heart Points', label='Running', ax=ax1)
ax1.set_xlabel('Proportion of Activity Duration')
ax1.set_ylabel('Heart Points')
ax1.set_title('Activity Duration vs. Heart Points')
ax1.legend()

# Boxplot (Distribution of Activity Duration Proportions) using Seaborn
duration_cols = ['Biking_proportion', 'Walking_proportion', 'Running_proportion']
sns.boxplot(data=df[duration_cols].dropna(axis=1), ax=ax2)
ax2.set_title('Distribution of Activity Duration Proportions')
ax2.set_ylabel('Proportion')
ax2.set_xlabel('Activity Types')

plt.tight_layout()
plt.show()

# %% [markdown]
# desc

# %%
# Calculate total duration for each activity type
df['Total_Biking'] = df['Biking duration (ms)'].sum()
df['Total_Walking'] = df['Walking duration (ms)'].sum()
df['Total_Running'] = df['Running duration (ms)'].sum()

# Calculate the contribution of each activity type to Heart Points and Calories
total_heart_points = df['Heart Points'].sum()
total_calories = df['Calories (kcal)'].sum()

contribution_heart_points = [
    df['Total_Biking'].sum() / total_heart_points,
    df['Total_Walking'].sum() / total_heart_points,
    df['Total_Running'].sum() / total_heart_points
]

contribution_calories = [
    df['Total_Biking'].sum() / total_calories,
    df['Total_Walking'].sum() / total_calories,
    df['Total_Running'].sum() / total_calories
]

labels = ['Biking', 'Walking', 'Running']

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.pie(contribution_heart_points, labels=labels, autopct='%1.1f%%')
plt.title('Contribution of Activity Types to Heart Points')
plt.subplot(1, 2, 2)
plt.pie(contribution_calories, labels=labels, autopct='%1.1f%%')
plt.title('Contribution of Activity Types to Calories')
plt.tight_layout()
plt.show()

# %% [markdown]
# desc

# %% [markdown]
# ### Trend Analysis

# %%
# Convertion of Calories to kilocalories (kcal)
df['Calories (kcal)'] = df['Calories (kcal)'] / 1000.0

# Group by date and aggregating metrics
daily_metrics = df.groupby('Date').agg({
    'Move Minutes count': 'sum',
    'Calories (kcal)': 'sum',
    'Heart Points': 'sum'
}).reset_index()

# Normalizing the metrics for better visualization
for col in ['Move Minutes count', 'Calories (kcal)', 'Heart Points']:
    daily_metrics[col] = (daily_metrics[col] - daily_metrics[col].min()) / (daily_metrics[col].max() - daily_metrics[col].min())

plt.figure(figsize=(10, 6))
plt.plot(daily_metrics['Date'], daily_metrics['Move Minutes count'], label='Move Minutes')
plt.plot(daily_metrics['Date'], daily_metrics['Calories (kcal)'], label='Calories (kcal)')
plt.plot(daily_metrics['Date'], daily_metrics['Heart Points'], label='Heart Points')
plt.xlabel('Date')
plt.ylabel('Normalized Metrics')
plt.title('Trend Analysis Over Time (Normalized)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# desc
